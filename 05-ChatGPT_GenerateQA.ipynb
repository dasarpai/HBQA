# %%
import pandas as pd

# %%
# from google.colab import drive
# drive.mount('/content/drive')

apipath = r'H:\\My Drive\\config\\hbqa.txt'
import configparser

config = configparser.ConfigParser()
config.read(apipath)
secret_key = config['global']['OPENAI_API_KEY']
datapath = config['global']['DATA_FOLDER']

# %%
df= pd.read_csv(datapath+'04-Chunk_with_Prompts.csv')
print(df.shape)
df.head(5)
# Out:
# (1963, 6)
#    Section_Id  Chunk_Id  Chunk_Letters  Chunk_Words  Chunk_Approx_Tokens  \
# 0  Book01_002         1           7511         1214               1615.0
# 1  Book01_002         2           7551         1261               1677.0
# 2  Book01_002         3           6986         1162               1545.0
# 3  Book01_002         4          10832         1949               2592.0
# 4  Book01_002         5           7755         1246               1657.0
#
#                                               Prompt
# 0  Write 4 unique questions, corresponding answer...
# 1  Write 5 unique questions, corresponding answer...
# 2  Write 4 unique questions, corresponding answer...
# 3  Write 7 unique questions, corresponding answer...
# 4  Write 4 unique questions, corresponding answer...

# %%
import openai

# %%
import openai
openai.api_key = secret_key
def get_qa(qa_prompt):
    try:
        response = openai.Completion.create(
            model="text-davinci-003",
            prompt=qa_prompt,
            max_tokens=1000,
            temperature=0,
            frequency_penalty=1
        )
        return response['choices'][0]['text']
    except:
        print("Error")
        return ""

# %%
start=300
end=350

for row in range(end-start):
    qa_prompt = df.loc[row,'Prompt']
    response = get_qa(qa_prompt)
    df.loc[row+start,"QA"] = response 
    print("Row: ", row+start)

#response = df['Prompt'].apply(get_qa)
# Out:
# C:\Users\hari_\AppData\Local\Temp\ipykernel_11128\2025832252.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '
# Question 1: What is the name of the great sage who composed the Mahabharata?
# Answer: The great sage who composed the Mahabharata is Krishna-Dwaipayana, also known as Vyasa.
#
# Question 2: Who recited the Mahabharata at Janamejaya's Snake-sacrifice?
# Answer: The Mahabharata was recited at Janamejaya's Snake-sacrifice by Vaisampayana under the direction of Dwaipayana himself.
#
# Question 3: How many Prajapatis were produced from Brahma's egg?
# Answer: Twenty-one Prajapatis were produced from Brahma's egg.
#
# Question 4: What are some of the topics discussed in Vyasa's book?
# Answer: Some of the topics discussed in Vyasa's book include precepts of religious duty and worldly profit, acts of illustrious saints and sovereigns, Vedas, Yoga, Dharma, Artha and Kama, rules for conduct of mankind and histories and discourses with various srutis.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[row+start,"QA"] = response
# Row:  300
# Row:  301
# Row:  302
# Row:  303
# Row:  304
# Row:  305
# Row:  306
# Row:  307
# Row:  308
# Row:  309
# Row:  310
# Row:  311
# Row:  312
# Row:  313
# Row:  314
# Row:  315
# Row:  316
# Row:  317
# Row:  318
# Row:  319
# Row:  320
# Row:  321
# Row:  322
# Row:  323
# Row:  324
# Row:  325
# Row:  326
# Row:  327
# Row:  328
# Row:  329
# Row:  330
# Row:  331
# Row:  332
# Row:  333
# Row:  334
# Row:  335
# Row:  336
# Row:  337
# Row:  338
# Row:  339
# Row:  340
# Row:  341
# Row:  342
# Row:  343
# Row:  344
# Row:  345
# Row:  346
# Row:  347
# Row:  348
# Row:  349

# %%
df=df.loc[df['QA'].notna(),:]

# %%
qa_file="05-QA_Chunk"+str(start)+"_"+str(end-1)+".csv"

# %%
df.to_csv(datapath+qa_file)

# %%
df
# Out:
#      Section_Id  Chunk_Id  Chunk_Letters  Chunk_Words  Chunk_Approx_Tokens  \
# 300  Book03_054       301           4331          733                975.0
# 301  Book03_055       302           3632          640                851.0
# 302  Book03_056       303           3692          664                883.0
# 303  Book03_057       304           6577         1123               1494.0
# 304  Book03_061       305           4952          886               1178.0
# 305  Book03_062       306           4051          726                966.0
# 306  Book03_063       307           5212          907               1206.0
# 307  Book03_064       308           8639         1488               1979.0
# 308  Book03_064       309           4800          830               1104.0
# 309  Book03_064       310           4960          884               1176.0
# 310  Book03_065       311           4851          846               1125.0
# 311  Book03_065       312           5921         1067               1419.0
# 312  Book03_066       313           3550          660                878.0
# 313  Book03_068       314           5761          978               1301.0
# 314  Book03_069       315           6611         1169               1555.0
# 315  Book03_070       316           3811          651                866.0
# 316  Book03_071       317           5161          901               1198.0
# 317  Book03_072       318           5909         1043               1387.0
# 318  Book03_073       319           5206          927               1233.0
# 319  Book03_074       320           4347          738                982.0
# 320  Book03_075       321           3766          640                851.0
# 321  Book03_076       322           7077         1249               1661.0
# 322  Book03_078       323           4703          839               1116.0
# 323  Book03_079       324           4174          713                948.0
# 324  Book03_080       325           4881          812               1080.0
# 325  Book03_082       326           5906         1038               1381.0
# 326  Book03_083       327          11001         1868               2484.0
# 327  Book03_085       328          11551         1971               2621.0
# 328  Book03_085       329           5154          858               1141.0
# 329  Book03_086       330           3597          608                809.0
# 330  Book03_087       331           4500          771               1025.0
# 331  Book03_088       332           4520          769               1023.0
# 332  Book03_090       333           5104          849               1129.0
# 333  Book03_091       334           3739          651                866.0
# 334  Book03_092       335           3935          678                902.0
# 335  Book03_093       336           4173          712                947.0
# 336  Book03_095       337           5043          848               1128.0
# 337  Book03_096       338           4669          800               1064.0
# 338  Book03_097       339           3659          641                853.0
# 339  Book03_099       340           6242         1092               1452.0
# 340  Book03_099       341           4670          806               1072.0
# 341  Book03_100       342           3943          681                906.0
# 342  Book03_101       343           4080          680                904.0
# 343  Book03_102       344           4094          707                940.0
# 344  Book03_104       345           3672          645                858.0
# 345  Book03_106       346           4317          760               1011.0
# 346  Book03_107       347           7243         1275               1696.0
# 347  Book03_107       348           3863          687                914.0
# 348  Book03_108       349           4769          837               1113.0
# 349  Book03_110       350           5023          905               1204.0
#
#                                                 Prompt  \
# 300  Write 3 unique questions, corresponding answer...
# 301  Write 2 unique questions, corresponding answer...
# 302  Write 2 unique questions, corresponding answer...
# 303  Write 4 unique questions, corresponding answer...
# 304  Write 3 unique questions, corresponding answer...
# 305  Write 3 unique questions, corresponding answer...
# 306  Write 3 unique questions, corresponding answer...
# 307  Write 5 unique questions, corresponding answer...
# 308  Write 3 unique questions, corresponding answer...
# 309  Write 3 unique questions, corresponding answer...
# 310  Write 3 unique questions, corresponding answer...
# 311  Write 4 unique questions, corresponding answer...
# 312  Write 2 unique questions, corresponding answer...
# 313  Write 3 unique questions, corresponding answer...
# 314  Write 4 unique questions, corresponding answer...
# 315  Write 2 unique questions, corresponding answer...
# 316  Write 3 unique questions, corresponding answer...
# 317  Write 4 unique questions, corresponding answer...
# 318  Write 3 unique questions, corresponding answer...
# 319  Write 3 unique questions, corresponding answer...
# 320  Write 2 unique questions, corresponding answer...
# 321  Write 4 unique questions, corresponding answer...
# 322  Write 3 unique questions, corresponding answer...
# 323  Write 3 unique questions, corresponding answer...
# 324  Write 3 unique questions, corresponding answer...
# 325  Write 4 unique questions, corresponding answer...
# 326  Write 7 unique questions, corresponding answer...
# 327  Write 7 unique questions, corresponding answer...
# 328  Write 3 unique questions, corresponding answer...
# 329  Write 2 unique questions, corresponding answer...
# 330  Write 3 unique questions, corresponding answer...
# 331  Write 3 unique questions, corresponding answer...
# 332  Write 3 unique questions, corresponding answer...
# 333  Write 2 unique questions, corresponding answer...
